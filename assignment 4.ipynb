# %%
print("Gemaakt op 23/04/2025 door martijn")
# Out:
# Gemaakt op 23/04/2025 door martijn

# %%
import pandas as pd
import seaborn as sns

# %%
my_data = pd.read_csv("./calendar_dataset_1970_2025_with_holidays.csv")
my_data
# Out:
#              date  year     month  day    weekday  season  is_weekend  \
# 0      1970-01-01  1970   January    1   Thursday  Winter       False
# 1      1970-01-02  1970   January    2     Friday  Winter       False
# 2      1970-01-03  1970   January    3   Saturday  Winter        True
# 3      1970-01-04  1970   January    4     Sunday  Winter        True
# 4      1970-01-05  1970   January    5     Monday  Winter       False
# ...           ...   ...       ...  ...        ...     ...         ...
# 20449  2025-12-27  2025  December   27   Saturday  Winter        True
# 20450  2025-12-28  2025  December   28     Sunday  Winter        True
# 20451  2025-12-29  2025  December   29     Monday  Winter       False
# 20452  2025-12-30  2025  December   30    Tuesday  Winter       False
# 20453  2025-12-31  2025  December   31  Wednesday  Winter       False
#
#              holiday  isMyBirthday
# 0      Nieuwjaarsdag         False
# 1                NaN         False
# ...

# %%
my_data["holiday"].value_counts(dropna=True).plot(kind="bar")
# Out:
# <Axes: xlabel='holiday'>

# %%
my_data[my_data["holiday"] == "Hemelvaartsdag"]
# Out:
#              date  year month  day   weekday  season  is_weekend  \
# 126    1970-05-07  1970   May    7  Thursday  Spring       False
# 504    1971-05-20  1971   May   20  Thursday  Spring       False
# 861    1972-05-11  1972   May   11  Thursday  Spring       False
# 1246   1973-05-31  1973   May   31  Thursday  Spring       False
# 1603   1974-05-23  1974   May   23  Thursday  Spring       False
# 1953   1975-05-08  1975   May    8  Thursday  Spring       False
# 2338   1976-05-27  1976   May   27  Thursday  Spring       False
# 2695   1977-05-19  1977   May   19  Thursday  Spring       False
# 3045   1978-05-04  1978   May    4  Thursday  Spring       False
# 3430   1979-05-24  1979   May   24  Thursday  Spring       False
# 3787   1980-05-15  1980   May   15  Thursday  Spring       False
# 4165   1981-05-28  1981   May   28  Thursday  Spring       False
# 4522   1982-05-20  1982   May   20  Thursday  Spring       False
# ...
